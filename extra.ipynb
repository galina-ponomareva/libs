# %% [markdown]
# #### Задание 1
# Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_wine

# %%
data = load_wine()

# %% [markdown]
# #### Задание 2
# Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
data_keys = data.keys()
data_keys
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# #### Задание 3
# Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.

# %%
data['data'].shape
# Out:
# (178, 13)

# %%
data['data']
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
data['feature_names']
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
print(data["DESCR"])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
#     Alcalinity of Ash:            10.6  30.0    19.5   3.3
#     Magnesium:                    70.0 162.0    99.7  14.3
#     Total Phenols:                0.98  3.88    2.29  0.63
#     Flavanoids:                   0.34  5.08    2.03  1.00
#     Nonflavanoid Phenols:         0.13  0.66    0.36  0.12
#     Proanthocyanins:              0.41  3.58    1.59  0.57
#     Colour Intensity:              1.3  13.0     5.1   2.3
#     Hue:                          0.48  1.71    0.96  0.23
#     OD280/OD315 of diluted wines: 1.27  4.00    2.61  0.71
#     Proline:                       278  1680     746   315
#     ============================= ==== ===== ======= =====
#
#     :Missing Attribute Values: None
#     :Class Distribution: class_0 (59), class_1 (71), class_2 (48)
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# This is a copy of UCI ML Wine recognition datasets.
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data
#
# The data is the results of a chemical analysis of wines grown in the same
# region in Italy by three different cultivators. There are thirteen different
# measurements taken for different constituents found in the three types of
# wine.
#
# Original Owners:
#
# Forina, M. et al, PARVUS -
# An Extendible Package for Data Exploration, Classification and Correlation.
# Institute of Pharmaceutical and Food Analysis and Technologies,
# Via Brigata Salerno, 16147 Genoa, Italy.
#
# Citation:
#
# Lichman, M. (2013). UCI Machine Learning Repository
# [https://archive.ics.uci.edu/ml]. Irvine, CA: University of California,
# School of Information and Computer Science.
#
# .. topic:: References
#
#   (1) S. Aeberhard, D. Coomans and O. de Vel,
#   Comparison of Classifiers in High Dimensional Settings,
#   Tech. Rep. no. 92-02, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Technometrics).
#
#   The data was used with many others for comparing various
#   classifiers. The classes are separable, though only RDA
#   has achieved 100% correct classification.
#   (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
#   (All results using the leave-one-out technique)
#
#   (2) S. Aeberhard, D. Coomans and O. de Vel,
#   "THE CLASSIFICATION PERFORMANCE OF RDA"
#   Tech. Rep. no. 92-01, (1992), Dept. of Computer Science and Dept. of
#   Mathematics and Statistics, James Cook University of North Queensland.
#   (Also submitted to Journal of Chemometrics).

# %% [markdown]
# #### Задание 4
# Сколько классов содержит целевая переменная датасета? Выведите названия классов.

# %%
# Три класса целевой переменной
data['target_names']
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %% [markdown]
# #### Задание 5
# На основе данных датасета (они содержатся в двумерном массиве Numpy) и названий признаков создайте датафрейм под названием X.

# %%
X = pd.DataFrame(data['data'], columns=data['feature_names'])

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %% [markdown]
# #### Задание 6
# Выясните размер датафрейма X и установите, имеются ли в нем пропущенные значения.

# %%
X.shape
# Out:
# (178, 13)

# %%
X.size
# Out:
# 2314

# %%
# Пропущенных значений нет
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
# dtypes: float64(13)
# memory usage: 18.2 KB

# %% [markdown]
# #### Задание 7
# Добавьте в датафрейм поле с классами вин в виде чисел, имеющих тип данных numpy.int64. Название поля - 'target'.

# %%
X['target'] = data['target']

# %%
X['target'] = X['target'].astype(np.int64)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
#  13  target                        178 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 19.6 KB

# %% [markdown]
# #### Задание 8
# Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.

# %%
X_corr = X.corr()
X_corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col0,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col1,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col2,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col3,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col4,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow5_col5,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow6_col6,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow7_col7,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow8_col8,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow9_col9,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow10_col10,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow11_col11,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow12_col12,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col1,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col4{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col2,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col6{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col3{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col5,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col6{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col7,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col3,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow10_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col8,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow6_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col9{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col10,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col8,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col2{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col11,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col2{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col12{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow0_col13,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow12_col2{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col0,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow9_col3{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col2,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow7_col10{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col3,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col9{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col4{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col5{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col6,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col11,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow12_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col7{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col8{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col10,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow11_col13{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col12{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow1_col13{
#             background-color:  #f7ad90;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col0{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col1,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow5_col0{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col3,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow12_col11{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col4,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col13{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col5{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col6{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col7{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col9{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col10{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col11{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow2_col12{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col0{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col1,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col5{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col7{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col8,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow9_col11{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col9{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col10{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col11{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col12{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow3_col13,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow5_col8{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col0{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col1,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow8_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow4_col6,#T_a57bd5d0_c717_11eb_9a4c_f4b5202167ecrow8_col10{
#             background-color:  #ecd3c5;
#             color:  #

# %% [markdown]
# #### Задание 9
# Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному значению превышает 0.5 (причем, само поле target не должно входить в этот список).

# %%
abs(X_corr['target']) > 0.5
# Out:
# alcohol                         False
# malic_acid                      False
# ash                             False
# alcalinity_of_ash                True
# magnesium                       False
# total_phenols                    True
# flavanoids                       True
# nonflavanoid_phenols            False
# proanthocyanins                 False
# color_intensity                 False
# hue                              True
# od280/od315_of_diluted_wines     True
# proline                          True
# target                           True
# Name: target, dtype: bool

# %%
high_corr = ['alcalinity_of_ash', 'total_phenols', 'flavanoids', 'hue', 'od280/od315_of_diluted_wines', 'proline']
high_corr
# Out:
# ['alcalinity_of_ash',
#  'total_phenols',
#  'flavanoids',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# #### Задание 10
# Удалите из датафрейма X поле с целевой переменной. Для всех признаков, названия которых содержатся в списке high_corr, вычислите квадрат их значений и добавьте в датафрейм X соответствующие поля с суффиксом '_2', добавленного к первоначальному названию признака. Итоговый датафрейм должен содержать все поля, которые, были в нем изначально, а также поля с признаками из списка high_corr, возведенными в квадрат. Выведите описание полей датафрейма X с помощью метода describe.

# %%
X.drop('target', axis=1, inplace=True)

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %%
for i in high_corr:
    X[i + '_2'] = X[i] ** 2

# %%
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  alcalinity_of_ash_2  \
# 0                          3.92   1065.0               243.36
# 1                          3.40   1050.0               125.44
# 2                          3.17   1185.0               345.96
# 3                          3.45   1480.0               282.24
# 4                          2.93    735.0               441.00
#
#    total_phenols_2  flavanoids_2   hue_2  od280/od315_of_diluted_wines_2  \
# 0           7.8400        9.3636  1.0816                         15.3664
# 1           7.0225        7.6176  1.1025                         11.5600
# 2           7.8400       10.4976  1.0609                         10.0489
# 3          14.8225       12.1801  0.7396                         11.9025
# 4           7.8400        7.2361  1.0816                          8.5849
#
#    proline_2
# 0  1134225.0
# 1  1102500.0
# 2  1404225.0
# 3  2190400.0
# 4   540225.0

# %%
X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#        alcalinity_of_ash_2  total_phenols_2  flavanoids_2       hue_2  \
# count           178.000000       178.000000    178.000000  178.000000
# mean            391.142865         5.657030      5.110049    0.968661
# std             133.671775         2.936294      4.211441    0.443798
# min             112.360000         0.960400      0.115600    0.230400
# 25%             295.840000         3.036325      1.452100    0.612325
# 50%             380.250000         5.546050      4.558250    0.931250
# 75%             462.250000         7.840000      8.265700    1.254400
# max             900.000000        15.054400     25.806400    2.924100
#
#        od280/od315_of_diluted_wines_2     proline_2
# count                      178.000000  1.780000e+02
# mean                         7.322155  6.564591e+05
# std                          3.584316  5.558591e+05
# min                          1.612900  7.728400e+04
# 25%                          3.754075  2.505010e+05
# 50%                          7.728400  4.536045e+05
# 75%                         10.048900  9.702250e+05
# max                         16.000000  2.822400e+06
